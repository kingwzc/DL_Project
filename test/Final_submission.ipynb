# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/DL/Final_submission/test')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/DL/Final_submission/test'

# %%
# !python run_test.py --data_dir "../data/" --verbose
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 198MB/s]
# 0 - Bounding Box Score: 0.009945
# 1 - Bounding Box Score: 0.007151
# 2 - Bounding Box Score: 0.0149
# 3 - Bounding Box Score: 0.01095
# 4 - Bounding Box Score: 0.01165
# 5 - Bounding Box Score: 0.01085
# 6 - Bounding Box Score: 0.005742
# 7 - Bounding Box Score: 0.01422
# 8 - Bounding Box Score: 0.01003
# 9 - Bounding Box Score: 0.006878
# ...
